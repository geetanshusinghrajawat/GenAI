# %%
# pip install gensim
# Out:
# ...
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.4 MB 5.6 MB/s eta 0:00:05
#    --- ------------------------------------ 1.8/24.4 MB 5.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 3.4/24.4 MB 6.5 MB/s eta 0:00:04
#    -------- ------------------------------- 5.0/24.4 MB 7.0 MB/s eta 0:00:03
#    --------- ------------------------------ 6.0/24.4 MB 6.5 MB/s eta 0:00:03
#    ------------- -------------------------- 8.4/24.4 MB 7.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 10.7/24.4 MB 8.1 MB/s eta 0:00:02
#    ------------------ --------------------- 11.5/24.4 MB 8.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 13.9/24.4 MB 7.9 MB/s eta 0:00:02
#    -------------------------- ------------- 16.3/24.4 MB 8.3 MB/s eta 0:00:01
#    ------------------------------ --------- 18.9/24.4 MB 8.7 MB/s eta 0:00:01
# ...

# %%
import gensim
from gensim.models import KeyedVectors

# %%
path = r"D:\Praticals\Generative AI\Natural Language Processing\Text Vectorization\Word2Vec\GoogleNews-vectors-negative300.bin.gz"
model = KeyedVectors.load_word2vec_format(path, binary=True,limit = 200000)

# %%
model['man']
# Out:
# array([ 0.32617188,  0.13085938,  0.03466797, -0.08300781,  0.08984375,
#        -0.04125977, -0.19824219,  0.00689697,  0.14355469,  0.0019455 ,
#         0.02880859, -0.25      , -0.08398438, -0.15136719, -0.10205078,
#         0.04077148, -0.09765625,  0.05932617,  0.02978516, -0.10058594,
#        -0.13085938,  0.001297  ,  0.02612305, -0.27148438,  0.06396484,
#        -0.19140625, -0.078125  ,  0.25976562,  0.375     , -0.04541016,
#         0.16210938,  0.13671875, -0.06396484, -0.02062988, -0.09667969,
#         0.25390625,  0.24804688, -0.12695312,  0.07177734,  0.3203125 ,
#         0.03149414, -0.03857422,  0.21191406, -0.00811768,  0.22265625,
#        -0.13476562, -0.07617188,  0.01049805, -0.05175781,  0.03808594,
#        -0.13378906,  0.125     ,  0.0559082 , -0.18261719,  0.08154297,
#        -0.08447266, -0.07763672, -0.04345703,  0.08105469, -0.01092529,
#         0.17480469,  0.30664062, -0.04321289, -0.01416016,  0.09082031,
# ...

# %% [markdown]
# ### ARITHMETIC OPERATIONS

# %%
model['man'] - model['women']
# Out:
# array([ 0.4658203 , -0.03320312,  0.01855469, -0.19091797, -0.12890625,
#         0.22241211, -0.08496094,  0.12652588,  0.21044922, -0.09424591,
#         0.14990234, -0.078125  , -0.20703125, -0.34472656, -0.07214355,
#        -0.1105957 ,  0.01611328,  0.04467773,  0.03536987, -0.2109375 ,
#         0.03320312, -0.03117371,  0.13598633,  0.0703125 ,  0.20947266,
#         0.01855469,  0.10449219,  0.08105469,  0.50683594,  0.13134766,
#         0.15968323,  0.16210938,  0.10986328,  0.16589355, -0.05615234,
#         0.15478516,  0.30810547,  0.00878906,  0.13769531,  0.19335938,
#         0.09448242, -0.1381836 ,  0.16015625,  0.03631592,  0.2388916 ,
#        -0.04052734, -0.00195312,  0.03979492, -0.23046875, -0.08496094,
#        -0.3857422 ,  0.21582031,  0.05767059, -0.3720703 ,  0.19189453,
#         0.23779297, -0.13378906, -0.04353905,  0.19580078, -0.01672363,
#         0.10351562,  0.3474121 ,  0.00610352,  0.01574707, -0.046875  ,
# ...

# %% [markdown]
# # SIMILARITY FUNCTION

# %%
model.similarity('man','women')
# Out:
# np.float32(0.2883053)

# %%
model.similarity('man','laptop')
# Out:
# np.float32(0.07082263)

# %%
model.doesnt_match(['PHP','JAVA', "Monkey"])
# Out:
# 'Monkey'

# %%
model.doesnt_match(['cricket','game','football','match','lamination'])
# Out:
# 'lamination'

# %%
model.most_similar(['cricket'])
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783),
#  ('Cricket_Board', 0.687838613986969)]

# %%
model.most_similar('king')
# Out:
# [('kings', 0.7138045430183411),
#  ('queen', 0.6510956883430481),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204220056533813),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864824056625366),
#  ('ruler', 0.5797567367553711),
#  ('princes', 0.5646552443504333),
#  ('throne', 0.5422105193138123),
#  ('royal', 0.5239794254302979)]

# %%
vec = model['king']-model['man'] +model['woman']

model.most_similar([vec])
# Out:
# [('king', 0.8449392318725586),
#  ('queen', 0.7300517559051514),
#  ('monarch', 0.645466148853302),
#  ('princess', 0.6156251430511475),
#  ('crown_prince', 0.5818676352500916),
#  ('prince', 0.5777117609977722),
#  ('kings', 0.5613663792610168),
#  ('sultan', 0.5376775860786438),
#  ('queens', 0.5289887189865112),
#  ('ruler', 0.5247419476509094)]
