# %%
import pandas as pd

# %%
d = pd.read_csv('test_data_cleaning.csv')

# %% [markdown]
# # WORD TOKENiZE
# ## Via SPLIT Function

# %%
t1 = "I am going to Delhi"

# %%
t1.split()
# Out:
# ['I', 'am', 'going', 'to', 'Delhi']

# %%
d.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about  # earthquake is different cities,...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN     Apocalypse lighting .   # Spokane  # wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
t2 = "I am going to Delhi . I will stay there for 3 days . If you are free at that time please let me know ."

# %%
t2.split('. ')
# Out:
# ['I am going to Delhi ',
#  'I will stay there for 3 days ',
#  'If you are free at that time please let me know .']

# %% [markdown]
# ## Regular Expression

# %%
import re

# %%
t1 = "I am @ going ! to ! Delhi!"

# %%
re.findall("[\w']+",t1) #Removes punctuations
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\geeta\AppData\Local\Temp\ipykernel_22072\549271155.py:1: SyntaxWarning: invalid escape sequence '\w'
#   re.findall("[\w']+",t1) #Removes punctuations
# ['I', 'am', 'going', 'to', 'Delhi']

# %%
t3 = "Hey how are you? I am fine ! I was searching!!! for you ."

# %%
re.compile('[.!?]').split(t3)
# Out:
# ['Hey how are you', ' I am fine ', ' I was searching', '', '', ' for you ', '']

# %% [markdown]
# # NLTK ---> NATURAL LANGUAGE TOOL KIT
# ### Used for word_splitting & sentence spilitting

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('punkt')
nltk.download('punkt_tab')

# %%
s1 = 'I have a Ph.D in A.I'

# %%
word_tokenize(s1)
# Out:
# ['I', 'have', 'a', 'Ph.D', 'in', 'A.I']

# %%
s2 = "we're her to help. mail us at abcd@gmail.com"

# %%
word_tokenize(s2)
# Out:
# ['we',
#  "'re",
#  'her',
#  'to',
#  'help',
#  '.',
#  'mail',
#  'us',
#  'at',
#  'abcd',
#  '@',
#  'gmail.com']

# %%
s3 = 'A 5km ride costs us $20.'

# %%
word_tokenize(s3)
# Out:
# ['A', '5km', 'ride', 'costs', 'us', '$', '20', '.']

# %%
t3 = "Hey how are you? I am fine ! I was searching for you ."

# %%
sent_tokenize(t3)
# Out:
# ['Hey how are you?', 'I am fine !', 'I was searching for you .']

# %% [markdown]
# ### NLTK library failed in suffix as well as punctuations
#
# ## To overcome this issue we use
#
# # SPACY library

# %%
#pip install spacy

# %%
import spacy
from spacy.cli import download
download('en_core_web_sm')

# %%
# Loading Dictionary
nlp = spacy.load('en_core_web_sm')

# %%
s1 = 'I have a Ph.D in A.I'
s2 = "we're here to help. mail us at abcd@gmail.com"
s3 = 'A 5km ride costs us $20.'

# %%
token1 = nlp(s3)

# %%
for i in token1:
    print(i)
# Out:
# A
# 5
# km
# ride
# costs
# us
# $
# 20
# .

# %% [markdown]
# # STEMMING

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
w1 = ['running','stories','runs','ran','easily','fairly']

# %%
for i in w1:
    print(ps.stem(i))
# Out:
# run
# stori
# run
# ran
# easili
# fairli

# %% [markdown]
# # Lemmitization

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# %%
# nltk.download('wordnet')
# nltk.download('omw-1.4')

# %%
wl = WordNetLemmatizer()

# %%
wl.lemmatize('running',pos = 'v')
# Out:
# 'run'

# %%
wl.lemmatize('better',pos = 'a')
# Out:
# 'good'

# %%
wl.lemmatize('mice',pos = 'n')
# Out:
# 'mouse'
