# %% [markdown]
# # DATA GETHERING USING API

# %% [markdown]
# #### https://api.themoviedb.org/3/genre/movie/list?api_key=abcd3e85654595e1379675ea3658936e&Language=en

# %%
import requests

# %%
requests.get('https://api.themoviedb.org/3/genre/movie/list?api_key=abcd3e85654595e1379675ea3658936e&Language=en')
# Out:
# <Response [200]>

# %%
url = 'https://api.themoviedb.org/3/trending/movie/day?api_key=abcd3e85654595e1379675ea3658936e&Language=en-US'

headers ={ 
    'accept': 'application/json',
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhYmNkM2U4NTY1NDU5NWUxMzc5Njc1ZWEzNjU4OTM2ZSIsIm5iZiI6MTc3MzA1MTk2MS43Nywic3ViIjoiNjlhZWEwMzkxYjI1NTY4MDAyNGViM2NhIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.mSKRm9Ji9Czf5mXBVRt76OFygA0-9n0nDN7pOMxECAc' \
}

response = requests.get(url = url, headers = headers)

print(response)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\geeta\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\geeta\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %% [markdown]
# ### THIS IS NOT WORKING BCS TMDB HAS NOT GRANTED IT'S PERMISSION TO THIS SERVER.
# ### THIS CODE WILL WORK IN GOOGLE COLAB. CHECK IT OUT WHILE REVISION <3.

# %%
response.json()

# %%
import pandas as pd
df = pd.DataFrame(response.json()['results'])

# %%
df.head()

# %%
df = df[['adult',	'id',	'title',	'original_title',	'overview','original_language','release_date','popularity','vote_average',	'vote_count']]

# %%
df.head()

# %%
df.shape

# %% [markdown]
# # VERY IMPORTANT

# %%
Final_Data = pd.DataFrame()
for i in range (1,501):


  url = f'https://api.themoviedb.org/3/trending/movie/day?api_key=abcd3e85654595e1379675ea3658936e&Language=en-US&page={i}'.format(i)

  headers ={ 
    'accept': 'application/json',
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhYmNkM2U4NTY1NDU5NWUxMzc5Njc1ZWEzNjU4OTM2ZSIsIm5iZiI6MTc3MzA1MTk2MS43Nywic3ViIjoiNjlhZWEwMzkxYjI1NTY4MDAyNGViM2NhIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.mSKRm9Ji9Czf5mXBVRt76OFygA0-9n0nDN7pOMxECAc' \
  }

  response = requests.get(url = url, headers = headers)

  df = pd.DataFrame(response.json()['results'])

  df = df[['adult',	'id',	'title',	'original_title',	'overview','original_language','release_date','popularity','vote_average',	'vote_count']]

  Final_Data = pd.concat([Final_Data,df],ignore_index = False)

# %%
Final_Data.to_csv('Trending Movies', index = False)

# %%
Final_Data.info()
