# %% [markdown]
# # Steps For EDA (Exploratory Data Analysis)
# ###
# #### Categorise the given column as a Numerical, Categorical, Mixed Data type columns
# ## Univariate Analysis ---> Numerical Column, Categorical Column
# ###
# ### Numerical Column Analysis ---> Distribution of Data ---> Histogram, kdeplot
# #### -->Finding Outliers ---> Boxplot
# #### -->handling Missing Values
# ###
# ### Categorical Column Analysis ---> Distribution of Data ---> countplot
# #### --> Missing Values
# ###
# ## Bivariate Analysis
# #### --> Numerical categorical Column --> ScatterPlot
# #### --> Numerical Categorical Column --> BarPlot
# #### --> Categorical Categorical column --> HeatMap

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df['Age'].describe()
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
df[df['Age'] == 76]
# Out:
#     PassengerId  Pclass                                               Name  \
# 96          988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
#
#        Sex   Age  SibSp  Parch Ticket   Fare Cabin Embarked
# 96  female  76.0      1      0  19877  78.85   C46        S

# %%
sns.boxplot(data = df, x = 'Age')
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(86)

# %%
df['Age'] = df['Age'].fillna(method = 'ffill')
# Out:
# C:\Users\geeta\AppData\Local\Temp\ipykernel_20624\2280943450.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'] = df['Age'].fillna(method = 'ffill')

# %%
sns.boxplot(data = df, x = 'Age')
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.histplot(data = df, x = 'Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.kdeplot(data = df, x= 'Age')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df['Fare'].describe()
# Out:
# count    417.000000
# mean      35.627188
# std       55.907576
# min        0.000000
# 25%        7.895800
# 50%       14.454200
# 75%       31.500000
# max      512.329200
# Name: Fare, dtype: float64
